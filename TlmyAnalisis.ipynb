# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./resources/tlmy.csv')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df["packetNumber"] = df["packetNumber"].astype(int)
df["OBCUpTime"] = df["OBCUpTime"].astype(int)
df["TempBatt"] = df["TempBatt"].astype(int)
df["frameType"] = df["frameType"].astype(int)
df["UTCTime"] = df["UTCTime"].astype(int)
df["dt"] = pd.to_datetime(df["UTCTime"], unit='s')

# %%
df.sort_values(by=['UTCTime'], inplace=True)
#df.set_index('packetNumber', inplace=True)

# %%
df = df.drop_duplicates(subset=['UTCTime'])
df.sort_values(by=['UTCTime'], inplace=True)

# %%
df.head(10)
# Out:
#        frameType  packetNumber  OBCUpTime     obcT1  TXcurrent  RXcurrent  \
# 22072          1          2448       2593  23.78885        0.0       62.0
# 21996          1          2449       2594  23.78885      372.0       62.0
# 1482           1          2451       2596  23.78885      375.0       62.0
# 4922           1          2453       2598  23.78885      375.0       62.0
# 22008          1          2455       2600  23.39894      376.0       62.0
# 1307           1          2457       2603  23.78885        0.0       62.0
# 10968          1          2459       2605  23.78885      375.0       62.0
# 1315           1          2461       2607  23.78885      375.0       62.0
# 1318           1          2463       2609  23.78885      375.0       62.0
# 4969           1          2465       2611  23.78885        0.0       62.0
#
#        TempBatt  IMTQ_temp     tempP1     UTCTime                  dt
# 22072        21       23.5  21.742188  1488696214 2017-03-05 06:43:34
# 21996        21       23.5  21.742188  1488696217 2017-03-05 06:43:37
# 1482         21       23.5  21.742188  1488696228 2017-03-05 06:43:48
# 4922         21       23.5  21.742188  1488696238 2017-03-05 06:43:58
# 22008        21       23.5  21.742188  1488696241 2017-03-05 06:44:01
# 1307         21       23.5  21.742188  1488696258 2017-03-05 06:44:18
# 10968        21       23.5  21.742188  1488696268 2017-03-05 06:44:28
# 1315         21       23.5  21.742188  1488696278 2017-03-05 06:44:38
# 1318         21       23.5  21.742188  1488696281 2017-03-05 06:44:41
# 4969         21       23.5  21.742188  1488696297 2017-03-05 06:44:57

# %%
plt.figure(figsize=(20,10))
dfr = df.iloc[6000:6100, :]
plt.plot(dfr['dt'], dfr['TXcurrent'])
plt.plot(dfr['dt'], dfr['RXcurrent'])
plt.show()

# %%
plt.figure(figsize=(20,10))
dfr = df.iloc[500:800, :]
cols = ['obcT1', 'TempBatt', 'IMTQ_temp', 'tempP1']
plt.figure(figsize=(20,10))
# Graficar las columnas seleccionadas
for c in cols:
    plt.plot(dfr['dt'], dfr[c], label=c)

# Añadir etiquetas y leyenda
plt.xlabel('dt')
plt.ylabel('temps')
plt.title('-')
plt.legend()

# Mostrar el gráfico
plt.show()
plt.show()

# %%
df[df.frameType != 1]
# Out:
# Empty DataFrame
# Columns: [frameType, packetNumber, OBCUpTime, obcT1, TXcurrent, RXcurrent, TempBatt, IMTQ_temp, tempP1, UTCTime, dt]
# Index: []
